# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import html5lib

# %%
import numpy as np
seasons = np.arange(9,21)

urls = []
for season in seasons:
    season_url = 'https://en.wikipedia.org/wiki/The_Bachelor_(season_{})'.format(season)
    urls.append(season_url)

# %%
def makeSoup(url):
    response=requests.get(url)
    soup=BeautifulSoup(response.content,"lxml")
    return soup

# %%
import re

def dataCollector(soup):
    this = makeSoup(soup)
    
    tables = this.findChildren('table')
    table = tables[1]
    
    data   = [[td.text for td in row.select('td')]
             for row in table.findAll('tr')]
    
    
    header = ['name','age', 'hometown', 'occupation', 'elimination']
    body = data[1:]
    cols   =  zip(*body)
    
    tbl_d  = {name:col for name, col in zip(header,cols)}
    
    number = re.findall(r'\d+', soup)
    
    # remove brackets
    num= ''.join(number)

    tbl_d['season'] = [num] * len(dic['age'])
    
    new_names = []
    for name in tbl_d['name']:
        cleaned_name = re.sub(r'\[\d+\]', ' ', name)
        new_names.append(cleaned_name)

    tbl_d['name'] = new_names
    
    return tbl_d

# %%
dic = dataCollector('https://en.wikipedia.org/wiki/The_Bachelor_(season_12)')

# %%
pd.DataFrame(dic)
# Out:
#    age elimination                     hometown                    name  \
# 0   22      Winner           Malibu, California           Shayne Lamas
# 1   25      Week 8            Durango, Colorado      Chelsea Wanstrath
# 2   27      Week 7           Niceville, Florida       Amanda Rantuccio
# 3   26      Week 6           Loveland, Colorado           Noelle Drake
# 4   27      Week 5           Brooklyn, New York       Marshana Ritchie
# 5   22      Week 5            Holland, Michigan         Robin Canfield
# 6   22      Week 4  Jacksonville Beach, Florida         Ashlee Williss
# 7   25      Week 4        Hollywood, California            Kelly Duncan
# 8   24      Week 4               Suffield, Ohio           Holly Durst
# 9   22      Week 3         Stockton, California                     Amy
# 10  33      Week 3           Venice, California              Erin Storm
# 11  33      Week 3      Dillsburg, Pennsylvania  Kristine Heffelfinger
# 12  28      Week 2           Syracuse, New York             Michelle P.
# 13  25      Week 2      Oklahoma City, Oklahoma         Carri Perrier
# 14  25      Week 2          Seattle, Washington           Erin Harper
# 15  24      Week 1                 Boise, Idaho                  Alyssa
# 16  26      Week 1        LaFollette, Tennessee       Amanda Petterman
# 17  30      Week 1              Washington, D.C                  Denise
# 18  24      Week 1                Austin, Texas                   Devon
# 19  23      Week 1               Tampa, Florida           Lesley Geyer
# 20  33      Week 1    Laguna Niguel, California              Michele R.
# 21  30      Week 1            Alamo, California                 Rebecca
# 22  26      Week 1            Chicago, Illinois            Stacey Elza
# 23  23      Week 1    Beverly Hills, California                  Tamara
# 24  33      Week 1    San Francisco, California                 Tiffany
#
#                               occupation season
# 0                                Actress     12
# 1              Pharmaceutical sales rep.     12
# 2                      Account Executive     12
# 3                           Photographer     12
# 4                       Fashion designer     12
# 5                Advertising coordinator     12
# 6                      Singer-songwriter     12
# 7                     Medical sales rep.     12
# 8                 Children's book author     12
# 9                                  Nanny     12
# 10                        Hot-dog vendor     12
# 11                      Personal trainer     12
# 12              Administrative assistant     12
